# %%
import pandas as pd
import os

# %%
DIRETORIO = 'C:\Projetos\coleta_dados_estruturados'
arquivo = 'dados_jogadores.csv'
dados = os.path.join(DIRETORIO, arquivo)
dados
# Out:
# 'C:\\Projetos\\coleta_dados_estruturados\\dados_jogadores.csv'

# %%
df = pd.read_csv('C:\\Projetos\\coleta_dados_estruturados\\dados_jogadores.csv', sep=';', encoding='latin-1')

# %%
df.rename(columns={'jogador': 'nome_jogador'}, inplace = True)

# %%
df['data_nascimento'] = pd.to_datetime(df['data_nascimento'])
df['Data'] = df['data_nascimento'].dt.strftime('%Y-%m-%d')

# %%
df.head()
# Out:
#   nome_jogador     genero data_nascimento           jogo       pais  \
# 0    jogador 1  Masculino      1990-03-09           Dama      Chile
# 1    Jogador 2   Feminino      1986-01-05  Jogo da velha      Chile
# 2    Jogador 3  Masculino      1964-04-10  Jogo da velha     Brasil
# 3    Jogador 4  Masculino      1979-09-28  Jogo da velha  Argentina
# 4    Jogador 5  Masculino      1978-03-09           Dama    Uruguai
#
#    num_vitorias  num_derrotas  total_partidas        Data
# 0          14.0           0.0            14.0  1990-03-09
# 1          39.0          20.0            59.0  1986-01-05
# 2          26.0           3.0            29.0  1964-04-10
# 3           9.0          72.0            81.0  1979-09-28
# 4           1.0          54.0            55.0  1978-03-09

# %%
# !pip install mysqlclient

# %%
# !pip install sqlalchemy

# %%
import MySQLdb
import sqlalchemy

# %%
user = 'root'
password = 'pedro7007'
host = 'localhost'
database = 'pedro' #schema

string_conexao = f'mysql://{user}:{password}@{host}/{database}'
string_conexao
# Out:
# 'mysql://root:pedro7007@localhost/pedro'

# %%
engine = sqlalchemy.create_engine(string_conexao)
conn = engine.connect()

# %%
df_jogador = df[['nome_jogador', 'genero', 'data_nascimento', 'num_vitorias', 'num_derrotas', 'total_partidas']].drop_duplicates().dropna()
df_jogo = df[['jogo']].drop_duplicates().dropna()
paiss = list(df.pais.unique())

# %%
df_jogador
# Out:
#     nome_jogador     genero data_nascimento  num_vitorias  num_derrotas  \
# 0      jogador 1  Masculino      1990-03-09          14.0           0.0
# 1      Jogador 2   Feminino      1986-01-05          39.0          20.0
# 2      Jogador 3  Masculino      1964-04-10          26.0           3.0
# 3      Jogador 4  Masculino      1979-09-28           9.0          72.0
# 4      Jogador 5  Masculino      1978-03-09           1.0          54.0
# ..           ...        ...             ...           ...           ...
# 493  Jogador 494   Feminino      1977-07-11          31.0          11.0
# 494  Jogador 495   Feminino      1974-03-06          52.0          28.0
# 495  Jogador 496  Masculino      1959-09-02          13.0          51.0
# 497  Jogador 498  Masculino      1958-09-28           5.0           3.0
# 498  Jogador 499   Feminino      2004-08-10           1.0          86.0
#
#      total_partidas
# 0              14.0
# 1              59.0
# 2              29.0
# ...

# %%
df_jogo
# Out:
#             jogo
# 0           Dama
# 1  Jogo da velha
# 5         Xadrez

# %%
paiss
# Out:
# ['Chile', 'Brasil', 'Argentina', 'Uruguai', 'Paraguai']

# %%
for jogado in df_jogador[:3].itertuples():
    print(jogado)
# Out:
# Pandas(Index=0, nome_jogador='jogador 1', genero='Masculino', data_nascimento=Timestamp('1990-03-09 00:00:00'), num_vitorias=14.0, num_derrotas=0.0, total_partidas=14.0)
# Pandas(Index=1, nome_jogador='Jogador 2', genero='Feminino', data_nascimento=Timestamp('1986-01-05 00:00:00'), num_vitorias=39.0, num_derrotas=20.0, total_partidas=59.0)
# Pandas(Index=2, nome_jogador='Jogador 3', genero='Masculino', data_nascimento=Timestamp('1964-04-10 00:00:00'), num_vitorias=26.0, num_derrotas=3.0, total_partidas=29.0)

# %%
df_jogador = df[['nome_jogador', 'genero', 'data_nascimento', 'num_vitorias', 'num_derrotas', 'total_partidas']].drop_duplicates().dropna()
df_jogo = df[['jogo']].drop_duplicates().dropna()
paiss = list(df.pais.unique())

# %%
for pessoa in df_jogador.itertuples():
    nome_jogador = pessoa.nome_jogador
    genero = pessoa.genero
    data_nascimento = str(pessoa.data_nascimento)[:10]
    num_vitorias = pessoa.num_vitorias
    num_derrotas = pessoa.num_derrotas
    total_partidas = pessoa.total_partidas
    try:
        querey = f"""insert into jogador (cod_jogador, nome_jogador, genero, data_nascimento, num_vitorias, num_derrotas, total_partidas ) 
                     values ('{cod_jogador}', '{nome_jogador}', '{genero}',  '{data_nascimento}', '{num_vitorias}', '{num_derrotas}', '{total_partidas}')"""      
        conn.execute(querey)      
        print(f"Registro inserido com sucesso: {jogador}")
    except Exception as e:        
        print(f"Não foi possível inserir o regristro {jogador}. O erro foi encontrado foi: {e}")
# Out:
# Não foi possível inserir o regristro Jogador 499. O erro foi encontrado foi: (MySQLdb._exceptions.IntegrityError) (1364, "Field 'cod_pais' doesn't have a default value")
# [SQL: insert into jogador (cod_jogador, nome_jogador, genero, data_nascimento, num_vitorias, num_derrotas, total_partidas )
#                      values ('498', 'jogador 1', 'Masculino',  '1990-03-09', '14.0', '0.0', '14.0')]
# (Background on this error at: http://sqlalche.me/e/14/gkpj)
# Não foi possível inserir o regristro Jogador 499. O erro foi encontrado foi: (MySQLdb._exceptions.IntegrityError) (1364, "Field 'cod_pais' doesn't have a default value")
# [SQL: insert into jogador (cod_jogador, nome_jogador, genero, data_nascimento, num_vitorias, num_derrotas, total_partidas )
#                      values ('498', 'Jogador 2', 'Feminino',  '1986-01-05', '39.0', '20.0', '59.0')]
# (Background on this error at: http://sqlalche.me/e/14/gkpj)
# ...

# %%
for pessoa in df_jogo.itertuples():
    jogo = pessoa.jogo
    try:
        querey = f"""insert into jogo (jogo ) 
                     values ('{cod_jogador}' )"""      
        conn.execute(querey)      
        print(f"Registro inserido com sucesso: {jogo}")
    except Exception as e:
        print(f"Não foi possível inserir o regristro {jogo}. O erro foi encontrado foi: {e}")
# Out:
# Não foi possível inserir o regristro Dama. O erro foi encontrado foi: (MySQLdb._exceptions.OperationalError) (1054, "Unknown column 'jogo' in 'field list'")
# [SQL: insert into jogo (jogo )
#                      values ('498' )]
# (Background on this error at: http://sqlalche.me/e/14/e3q8)
# Não foi possível inserir o regristro Jogo da velha. O erro foi encontrado foi: (MySQLdb._exceptions.OperationalError) (1054, "Unknown column 'jogo' in 'field list'")
# [SQL: insert into jogo (jogo )
#                      values ('498' )]
# (Background on this error at: http://sqlalche.me/e/14/e3q8)
# Não foi possível inserir o regristro Xadrez. O erro foi encontrado foi: (MySQLdb._exceptions.OperationalError) (1054, "Unknown column 'jogo' in 'field list'")
# [SQL: insert into jogo (jogo )
#                      values ('498' )]
# (Background on this error at: http://sqlalche.me/e/14/e3q8)
